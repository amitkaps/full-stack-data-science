# %% [markdown]
# # Interactive Dashboard

# %% [markdown]
# The python visualisation landscape is rich and diverse. But also, given the diversity of the tools - it is hard for vis libraries, it has a lot of challenges in learning libraries and varying degree of maturity for the tools.
#
# See this PyCon 2017 Talk from JakeVandeplas on the Landscape
#
# - Speakerdeck link: https://speakerdeck.com/jakevdp/pythons-visualization-landscape-pycon-2017
# - Youtube link: https://www.youtube.com/watch?v=FytuB8nFHPQ
# - Github link: https://github.com/jakevdp/python-vis-landscape
#
# <img src="img/python_viz.png" alt="python-viz" style="width: 600px; height: 400px"/>

# %% [markdown]
# We will use a tool called `facet-dive` for multidimensional exploration of data

# %% [markdown]
# ## Facet-Dive: Interactive Exploration of Data and Classification
#
# Installation Instruction:
#
#     git clone https://github.com/PAIR-code/facets
#     cd facets
#     conda install protobuf
#     jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/default.csv")

# %%
df.head()
# Out:
#    default  amount grade  years ownership   income  age  y_pred  y_proba
# 0        0    1000     B    2.0      RENT  19200.0   24       0     0.15
# 1        1    6500     A    2.0  MORTGAGE  66000.0   28       1     0.80
# 2        0    2400     A    2.0      RENT  60000.0   36       0     0.08
# 3        0   10000     C    3.0      RENT  62000.0   24       0     0.05
# 4        1    4000     C    2.0      RENT  20000.0   28       1     0.82

# %%
jsonstr = df.to_json(orient='records')

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML

HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"default":0,"amount":1000,"grade":"B","years":2.0,"ownership":"RENT","income":19200.0,"age":24,"y_pred":0,"y_proba":0.15},{"default":1,"amount":6500,"grade":"A","years":2.0,"ownership":"MORTGAGE","income":66000.0,"age":28,"y_pred":1,"y_proba":0.8},{"default":0,"amount":2400,"grade":"A","years":2.0,"ownership":"RENT","income":60000.0,"age":36,"y_pred":0,"y_proba":0.08},{"default":0,"amount":10000,"grade":"C","years":3.0,"ownership":"RENT","income":62000.0,"age":24,"y_pred":0,"y_proba":0.05},{"default":1,"amount":4000,"grade":"C","years":2.0,"ownership":"RENT","income":20000.0,"age":28,"y_pred":1,"y_proba":0.82},{"default":1,"amount":5000,"grade":"A","years":2.0,"ownership":"RENT","income":12000.0,"age":27,"y_pred":1,"y_proba":0.82},{"default":1,"amount":6000,"grade":"C","years":1.0,"ownership":"RENT","income":48000.0,"age":23,"y_pred":1,"y_proba":0.86},{"default":0,"amount":5000,"grade":"D","years":2.0,"ownership":"RENT","income":40000.0,"age":21,"y_pred":0,"y_proba":0.13},{"default":0,"amount":4200,"grade":"A","years":6.0,"ownership":"RENT","income":60000.0,"age":29,"y_pred":0,"y_proba":0.05},{"default":0,"amount":12000,"grade":"A","years":4.0,"ownership":"MORTGAGE","income":85000.0,"age":22,"y_pred":0,"y_proba":0.04},{"default":1,"amount":3600,"grade":"A","years":3.0,"ownership":"RENT","income":70000.0,"age":27,"y_pred":1,"y_proba":0.66},{"default":0,"amount":6000,"grade":"B","years":1.0,"ownership":"RENT","income":72000.0,"age":25,"y_pred":0,"y_proba":0.13},{"default":1,"amount":4000,"grade":"A","years":2.0,"ownership":"RENT","income":54000.0,"age":27,"y_pred":1,"y_proba":0.89},{"default":0,"amount":13000,"grade":"C","years":2.0,"ownership":"MORTGAGE","income":65000.0,"age":22,"y_pred":0,"y_proba":0.07},{"default":1,"amount":1500,"grade":"A","years":3.0,"ownership":"RENT","income":45000.0,"age":24,"y_pred":1,"y_proba":0.9},{"default":1,"amount":4800,"grade":"D","years":2.0,"ownership":"RENT","income":75000.0,"age":24,"y_pred":1,"y_proba":0.93},{"default":1,"amount":1200,"grade":"C","years":0.0,"ownership":"RENT","income":4800.0,"age":22,"y_pred":1,"y_proba":0.67},{"default":0,"amount":7000,"grade":"A","years":0.0,"ownership":"RENT","income":75800.0,"age":23,"y_pred":0,"y_proba":0.15},{"default":1,"amount":12000,"grade":"C","years":3.0,"ownership":"MORTGAGE","income":40000.0,"age":23,"y_pred":1,"y_proba":0.88},{"default":0,"amount":10000,"grade":"D","years":2.0,"ownership":"RENT","income":90000.0,"age":21,"y_pred":0,"y_proba":0.17},{"default":0,"amount":2475,"grade":"A","years":16.0,"ownership":"MORTGAGE","income":63600.0,"age":23,"y_pred":0,"y_proba":0.06},{"default":1,"amount":7000,"grade":"C","years":0.0,"ownership":"RENT","income":54000.0,"age":28,"y_pred":1,"y_proba":0.82},{"default":0,"amount":10000,"grade":"D","years":1.0,"ownership":"RENT","income":72000.0,"age":38,"y_pred":0,"y_proba":0.12},{"default":0,"amount":7200,"grade":"D","years":1.0,"ownership":"OWN","income":42996.0,"age":25,"y_pred":0,"y_proba":0.16},{"default":1,"amount":7600,"grade":"C","years":1.0,"ownership":"RENT","income":67680.0,"age":25,"y_pred":1,"y_proba":0.76},{"default":0,"amount":1800,"grade":"A","years":12.0,"ownership":"RENT","income":35000.0,"age":29,"y_pred":0,"y_proba":0.29},{"default":0,"amount":7200,"grade":"B","years":1.0,"ownership":"MORTGAGE","income":73200.0,"age":32,"y_pred":0,"y_proba":0.22},{"default":0,"amount":2600,"grade":"B","years":2.0,"ownership":"RENT","income":40792.0,"age":35,"y_pred":0,"y_proba":0.18},{"default":0,"amount":7000,"grade":"B","years":0.0,"ownership":"MORTGAGE","income":85000.0,"age":23,"y_pred":0,"y_proba":0.18},{"default":0,"amount":12000,"grade":"B","years":11.0,"ownership":"MORTGAGE","income":136000.0,"age":32,"y_pred":0,"y_proba":0.05},{"default":0,"amount":7875,"grade":"B","years":15.0,"ownership":"MORTGAGE","income":55500.0,"age":36,"y_pred":0,"y_proba":0.11},{"default":0,"amount":6000,"grade":"A","years":0.0,"ownership":"RENT","income":26400.0,"age":22,"y_pred":0,"y_proba":0.18 ...
